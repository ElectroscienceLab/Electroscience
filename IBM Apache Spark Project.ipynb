# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# ![](http://spark.apache.org/images/spark-logo.png)

# %% [markdown]
# # **Final Project: Data Analysis using Spark SQL**
#
# Estimated time needed: **60** minutes
#
# This final project is similar to the Practice Project you did. In this project, you will not be provided with hints or solutions. You will create a DataFrame by loading data from a CSV file and apply transformations and actions using Spark SQL. This needs to be achieved by performing the following tasks:
#
# - Task 1: Generate DataFrame from CSV data.
# - Task 2: Define a schema for the data.
# - Task 3: Display schema of DataFrame.
# - Task 4: Create a temporary view.
# - Task 5: Execute an SQL query.
# - Task 6: Calculate Average Salary by Department.
# - Task 7: Filter and Display IT Department Employees.
# - Task 8: Add 10% Bonus to Salaries.
# - Task 9: Find Maximum Salary by Age.
# - Task 10: Self-Join on Employee Data.
# - Task 11: Calculate Average Employee Age.
# - Task 12: Calculate Total Salary by Department.
# - Task 13: Sort Data by Age and Salary.
# - Task 14: Count Employees in Each Department.
# - Task 15: Filter Employees with the letter o in the Name.

# %% [markdown]
# ### Prerequisites
#
# 1. For this lab assignment, you will be using Python and Spark (PySpark). Therefore, it's essential to make sure that the following libraries are installed in your lab environment or within Skills Network (SN) Labs

# %%
# Installing required packages  

# !pip install pyspark  findspark wget
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.4/311.4 MB 1.6 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 kB 34.8 MB/s eta 0:00:00
# ...
#   Created wheel for pyspark: filename=pyspark-3.4.3-py2.py3-none-any.whl size=311885504 sha256=a39cb9e6adeed0fc1f7353c0eaaddc1a4db04765fb41ea1acb34a4948e0f8ebf
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/37/bc/bb/77785f6fcd2c83e663647f73225b76f3a3d5fd00762d7daf6f
# Successfully built pyspark
# ...

# %%
import findspark

findspark.init()

# %%
# PySpark is the Spark API for Python. In this lab, we use PySpark to initialize the SparkContext.   

from pyspark import SparkContext, SparkConf

from pyspark.sql import SparkSession

# %%
# Creating a SparkContext object  

sc = SparkContext.getOrCreate()

# Creating a SparkSession  

spark = SparkSession \
    .builder \
    .appName("Python Spark DataFrames basic example") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://jupyterlab-kniewitecki:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>pyspark-shell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# 2. Download the CSV data.

# %%
# Download the CSV data first into a local `employees.csv` file
import wget
wget.download("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0225EN-SkillsNetwork/data/employees.csv")
# Out:
# 'employees.csv'

# %% [markdown]
# 2. Import PySpark Functions.

# %%
# In PySpark, the 'pyspark.sql.functions' module provides a collection of functions that can be used to 
# manipulate and transform data within DataFrames. We import neccessary functions for our operations later:

from pyspark.sql.functions import max #This function computes the maximum value of a specified column
from pyspark.sql.functions import avg #This function computes the average value of a specified column
from pyspark.sql.functions import sum #This function computes the sum of values in a specified column 
from pyspark.sql.functions import count #This function counts the number of rows for which the specified column is not null
from pyspark.sql.functions import col #This function returns a column based on the column name provided

# %% [markdown]
# ### Tasks

# %% [markdown]
# #### Task 1: Generate a Spark DataFrame from the CSV data
#
# Read data from the provided CSV file, `employees.csv` and import it into a Spark DataFrame variable named `employees_df`.

# %%
# Read data from the "emp" CSV file and import it into a DataFrame variable named "employees_df"  
employees_df = spark.read.option("header", "true").csv("employees.csv")

# Show the DataFrame
employees_df.show()
# Out:
# +------+---------+------+---+----------+
# |Emp_No| Emp_Name|Salary|Age|Department|
# +------+---------+------+---+----------+
# |   198|   Donald|  2600| 29|        IT|
# |   199|  Douglas|  2600| 34|     Sales|
# |   200| Jennifer|  4400| 36| Marketing|
# |   201|  Michael| 13000| 32|        IT|
# |   202|      Pat|  6000| 39|        HR|
# |   203|    Susan|  6500| 36| Marketing|
# |   204|  Hermann| 10000| 29|   Finance|
# |   205|  Shelley| 12008| 33|   Finance|
# |   206|  William|  8300| 37|        IT|
# |   100|   Steven| 24000| 39|        IT|
# |   101|    Neena| 17000| 27|     Sales|
# |   102|      Lex| 17000| 37| Marketing|
# |   103|Alexander|  9000| 39| Marketing|
# |   104|    Bruce|  6000| 38|        IT|
# |   105|    David|  4800| 39|        IT|
# |   106|    Valli|  4800| 38|     Sales|
# |   107|    Diana|  4200| 35|     Sales|
# |   108|    Nancy| 12008| 28|     Sales|
# |   109|   Daniel|  9000| 35|        HR|
# |   110|     John|  8200| 31| Marketing|
# ...

# %% [markdown]
# #### Task 2: Define a schema for the data
#
# Construct a schema for the input data and then utilize the defined schema to read the CSV file to create a DataFrame named `employees_df`.

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType

# Define a Schema for the input data and read the file using the user-defined Schema

spark = SparkSession.builder \
    .appName("Read CSV with Schema") \
    .getOrCreate()

# Define the schema
schema = StructType([
    StructField("Emp_No", IntegerType(), True),
    StructField("Emp_Name", StringType(), True),
    StructField("Salary", IntegerType(), True),
    StructField("Age", FloatType(), True),
    StructField("Department", StringType(), True)
])

employees_df = spark.read.schema(schema).option("header", "true").csv("employees.csv")

# Show the DataFrame
employees_df.show()
# Out:
# +------+---------+------+----+----------+
# |Emp_No| Emp_Name|Salary| Age|Department|
# +------+---------+------+----+----------+
# |   198|   Donald|  2600|29.0|        IT|
# |   199|  Douglas|  2600|34.0|     Sales|
# |   200| Jennifer|  4400|36.0| Marketing|
# |   201|  Michael| 13000|32.0|        IT|
# |   202|      Pat|  6000|39.0|        HR|
# |   203|    Susan|  6500|36.0| Marketing|
# |   204|  Hermann| 10000|29.0|   Finance|
# |   205|  Shelley| 12008|33.0|   Finance|
# |   206|  William|  8300|37.0|        IT|
# |   100|   Steven| 24000|39.0|        IT|
# |   101|    Neena| 17000|27.0|     Sales|
# |   102|      Lex| 17000|37.0| Marketing|
# |   103|Alexander|  9000|39.0| Marketing|
# |   104|    Bruce|  6000|38.0|        IT|
# |   105|    David|  4800|39.0|        IT|
# |   106|    Valli|  4800|38.0|     Sales|
# |   107|    Diana|  4200|35.0|     Sales|
# |   108|    Nancy| 12008|28.0|     Sales|
# |   109|   Daniel|  9000|35.0|        HR|
# ...

# %% [markdown]
# #### Task 3: Display schema of DataFrame
#
# Display the schema of the `employees_df` DataFrame, showing all columns and their respective data types.

# %%
# Display all columns of the DataFrame, along with their respective data types
employees_df.printSchema()
# Out:
# root
#  |-- Emp_No: integer (nullable = true)
#  |-- Emp_Name: string (nullable = true)
#  |-- Salary: integer (nullable = true)
#  |-- Age: float (nullable = true)
#  |-- Department: string (nullable = true)

# %% [markdown]
# #### Task 4: Create a temporary view
#
# Create a temporary view named `employees` for the `employees_df` DataFrame, enabling Spark SQL queries on the data.

# %%
# Create a temporary view named "employees" for the DataFrame
employees_df.createOrReplaceTempView("employees")

# Display the temporary view
spark.sql("SELECT * FROM employees").show()
# Out:
# +------+---------+------+----+----------+
# |Emp_No| Emp_Name|Salary| Age|Department|
# +------+---------+------+----+----------+
# |   198|   Donald|  2600|29.0|        IT|
# |   199|  Douglas|  2600|34.0|     Sales|
# |   200| Jennifer|  4400|36.0| Marketing|
# |   201|  Michael| 13000|32.0|        IT|
# |   202|      Pat|  6000|39.0|        HR|
# |   203|    Susan|  6500|36.0| Marketing|
# |   204|  Hermann| 10000|29.0|   Finance|
# |   205|  Shelley| 12008|33.0|   Finance|
# |   206|  William|  8300|37.0|        IT|
# |   100|   Steven| 24000|39.0|        IT|
# |   101|    Neena| 17000|27.0|     Sales|
# |   102|      Lex| 17000|37.0| Marketing|
# |   103|Alexander|  9000|39.0| Marketing|
# |   104|    Bruce|  6000|38.0|        IT|
# |   105|    David|  4800|39.0|        IT|
# |   106|    Valli|  4800|38.0|     Sales|
# |   107|    Diana|  4200|35.0|     Sales|
# |   108|    Nancy| 12008|28.0|     Sales|
# |   109|   Daniel|  9000|35.0|        HR|
# ...

# %% [markdown]
# #### Task 5: Execute an SQL query
#
# Compose and execute an SQL query to fetch the records from the `employees` view where the age of employees exceeds 30. Then, display the result of the SQL query, showcasing the filtered records.

# %%
# SQL query to fetch solely the records from the View where the age exceeds 30
result_df = spark.sql("SELECT * FROM employees WHERE Age > 30")
result_df.show()
# Out:
# +------+-----------+------+----+----------+
# |Emp_No|   Emp_Name|Salary| Age|Department|
# +------+-----------+------+----+----------+
# |   199|    Douglas|  2600|34.0|     Sales|
# |   200|   Jennifer|  4400|36.0| Marketing|
# |   201|    Michael| 13000|32.0|        IT|
# |   202|        Pat|  6000|39.0|        HR|
# |   203|      Susan|  6500|36.0| Marketing|
# |   205|    Shelley| 12008|33.0|   Finance|
# |   206|    William|  8300|37.0|        IT|
# |   100|     Steven| 24000|39.0|        IT|
# |   102|        Lex| 17000|37.0| Marketing|
# |   103|  Alexander|  9000|39.0| Marketing|
# |   104|      Bruce|  6000|38.0|        IT|
# |   105|      David|  4800|39.0|        IT|
# |   106|      Valli|  4800|38.0|     Sales|
# |   107|      Diana|  4200|35.0|     Sales|
# |   109|     Daniel|  9000|35.0|        HR|
# |   110|       John|  8200|31.0| Marketing|
# |   111|     Ismael|  7700|32.0|        IT|
# |   112|Jose Manuel|  7800|34.0|        HR|
# ...

# %% [markdown]
# #### Task 6: Calculate Average Salary by Department
#
# Compose an SQL query to retrieve the average salary of employees grouped by department. Display the result.

# %%
# SQL query to calculate the average salary of employees grouped by department
avg_salary_df = spark.sql("SELECT Department, AVG(Salary) as Average_Salary FROM employees GROUP BY Department")
avg_salary_df.show()
# Out:
# [Stage 20:============================================>           (59 + 9) / 75]
# +----------+-----------------+
# |Department|   Average_Salary|
# +----------+-----------------+
# |     Sales|5492.923076923077|
# |        HR|           5837.5|
# |   Finance|           5730.8|
# | Marketing|6633.333333333333|
# |        IT|           7400.0|
# +----------+-----------------+

# %% [markdown]
# #### Task 7: Filter and Display IT Department Employees
#
# Apply a filter on the `employees_df` DataFrame to select records where the department is `'IT'`. Display the filtered DataFrame.

# %%
# Apply a filter to select records where the department is 'IT'
it_employees_df = employees_df.filter(employees_df.Department == 'IT')

# Display the filtered DataFrame
it_employees_df.show()
# Out:
# +------+--------+------+----+----------+
# |Emp_No|Emp_Name|Salary| Age|Department|
# +------+--------+------+----+----------+
# |   198|  Donald|  2600|29.0|        IT|
# |   201| Michael| 13000|32.0|        IT|
# |   206| William|  8300|37.0|        IT|
# |   100|  Steven| 24000|39.0|        IT|
# |   104|   Bruce|  6000|38.0|        IT|
# |   105|   David|  4800|39.0|        IT|
# |   111|  Ismael|  7700|32.0|        IT|
# |   129|   Laura|  3300|38.0|        IT|
# |   132|      TJ|  2100|34.0|        IT|
# |   136|   Hazel|  2200|29.0|        IT|
# +------+--------+------+----+----------+

# %% [markdown]
# #### Task 8: Add 10% Bonus to Salaries
#
# Perform a transformation to add a new column named "SalaryAfterBonus" to the DataFrame. Calculate the new salary by adding a 10% bonus to each employee's salary.

# %%
# Add a new column "SalaryAfterBonus" with 10% bonus added to the original salary
employees_with_bonus_df = employees_df.withColumn("SalaryAfterBonus", col("Salary") * 1.10)

# Display the result
employees_with_bonus_df.show()
# Out:
# +------+---------+------+----+----------+------------------+
# |Emp_No| Emp_Name|Salary| Age|Department|  SalaryAfterBonus|
# +------+---------+------+----+----------+------------------+
# |   198|   Donald|  2600|29.0|        IT|2860.0000000000005|
# |   199|  Douglas|  2600|34.0|     Sales|2860.0000000000005|
# |   200| Jennifer|  4400|36.0| Marketing|            4840.0|
# |   201|  Michael| 13000|32.0|        IT|14300.000000000002|
# |   202|      Pat|  6000|39.0|        HR| 6600.000000000001|
# |   203|    Susan|  6500|36.0| Marketing| 7150.000000000001|
# |   204|  Hermann| 10000|29.0|   Finance|           11000.0|
# |   205|  Shelley| 12008|33.0|   Finance|13208.800000000001|
# |   206|  William|  8300|37.0|        IT|            9130.0|
# |   100|   Steven| 24000|39.0|        IT|26400.000000000004|
# |   101|    Neena| 17000|27.0|     Sales|           18700.0|
# |   102|      Lex| 17000|37.0| Marketing|           18700.0|
# ...

# %% [markdown]
# #### Task 9: Find Maximum Salary by Age
#
# Group the data by age and calculate the maximum salary for each age group. Display the result.

# %%
# here we use 'from pyspark.sql.functions import max' - imported earlier

# Group data by age and calculate the maximum salary for each age group
max_salary_by_age_df = employees_df.groupBy("Age").agg(max("Salary").alias("MaxSalary"))

# Display the result
max_salary_by_age_df.show()
# Out:
# +----+---------+
# | Age|MaxSalary|
# +----+---------+
# |39.0|    24000|
# |30.0|     8000|
# |26.0|     3600|
# |29.0|    10000|
# |38.0|     6000|
# |27.0|    17000|
# |35.0|     9000|
# |34.0|     7800|
# |32.0|    13000|
# |36.0|     7900|
# |33.0|    12008|
# |31.0|     8200|
# |28.0|    12008|
# |37.0|    17000|
# +----+---------+

# %% [markdown]
# #### Task 10: Self-Join on Employee Data
#
# Join the "employees_df" DataFrame with itself based on the "Emp_No" column. Display the result.

# %%
# Join the DataFrame with itself based on the "Emp_No" column
joined_df = employees_df.alias("df1").join(employees_df.alias("df2"), col("df1.Emp_No") == col("df2.Emp_No"))

# Display the result
joined_df.show()
# Out:
# +------+---------+------+----+----------+------+---------+------+----+----------+
# |Emp_No| Emp_Name|Salary| Age|Department|Emp_No| Emp_Name|Salary| Age|Department|
# +------+---------+------+----+----------+------+---------+------+----+----------+
# |   198|   Donald|  2600|29.0|        IT|   198|   Donald|  2600|29.0|        IT|
# |   199|  Douglas|  2600|34.0|     Sales|   199|  Douglas|  2600|34.0|     Sales|
# |   200| Jennifer|  4400|36.0| Marketing|   200| Jennifer|  4400|36.0| Marketing|
# |   201|  Michael| 13000|32.0|        IT|   201|  Michael| 13000|32.0|        IT|
# |   202|      Pat|  6000|39.0|        HR|   202|      Pat|  6000|39.0|        HR|
# |   203|    Susan|  6500|36.0| Marketing|   203|    Susan|  6500|36.0| Marketing|
# |   204|  Hermann| 10000|29.0|   Finance|   204|  Hermann| 10000|29.0|   Finance|
# |   205|  Shelley| 12008|33.0|   Finance|   205|  Shelley| 12008|33.0|   Finance|
# ...

# %% [markdown]
# #### Task 11: Calculate Average Employee Age
#
# Calculate the average age of employees using the built-in aggregation function. Display the result.

# %%
# here we use 'from pyspark.sql.functions import avg' - imported earlier

# Calculate the average age of employees
avg_age = employees_df.agg(avg("Age").alias("AverageAge"))

# Display the result
avg_age.show()
# Out:
# +----------+
# |AverageAge|
# +----------+
# |     33.56|
# +----------+

# %% [markdown]
# #### Task 12: Calculate Total Salary by Department
#
# Calculate the total salary for each department using the built-in aggregation function. Display the result.

# %%
# here we use 'from pyspark.sql.functions import sum' - imported earlier

# Calculate the total salary for each department. Hint - User GroupBy and Aggregate functions
total_salary_by_dept_df = employees_df.groupBy("Department").agg(sum("Salary").alias("TotalSalary"))

# Display the result
total_salary_by_dept_df.show()
# Out:
# +----------+-----------+
# |Department|TotalSalary|
# +----------+-----------+
# |     Sales|      71408|
# |        HR|      46700|
# |   Finance|      57308|
# | Marketing|      59700|
# |        IT|      74000|
# +----------+-----------+

# %% [markdown]
# #### Task 13: Sort Data by Age and Salary
#
# Apply a transformation to sort the DataFrame by age in ascending order and then by salary in descending order. Display the sorted DataFrame.

# %%
# here we use 'from pyspark.sql.functions import col' - imported earlier

# Sort the DataFrame by age in ascending order and then by salary in descending order
sorted_df = employees_df.orderBy(col("Age").asc(), col("Salary").desc())

# Display the sorted DataFrame
sorted_df.show()
# Out:
# +------+---------+------+----+----------+
# |Emp_No| Emp_Name|Salary| Age|Department|
# +------+---------+------+----+----------+
# |   137|   Renske|  3600|26.0| Marketing|
# |   101|    Neena| 17000|27.0|     Sales|
# |   114|      Den| 11000|27.0|   Finance|
# |   108|    Nancy| 12008|28.0|     Sales|
# |   130|    Mozhe|  2800|28.0| Marketing|
# |   126|    Irene|  2700|28.0|        HR|
# |   204|  Hermann| 10000|29.0|   Finance|
# |   115|Alexander|  3100|29.0|   Finance|
# |   134|  Michael|  2900|29.0|     Sales|
# |   198|   Donald|  2600|29.0|        IT|
# |   140|   Joshua|  2500|29.0|   Finance|
# |   136|    Hazel|  2200|29.0|        IT|
# |   120|  Matthew|  8000|30.0|        HR|
# |   110|     John|  8200|31.0| Marketing|
# |   127|    James|  2400|31.0|        HR|
# |   201|  Michael| 13000|32.0|        IT|
# |   111|   Ismael|  7700|32.0|        IT|
# |   119|    Karen|  2500|32.0|   Finance|
# |   205|  Shelley| 12008|33.0|   Finance|
# ...

# %% [markdown]
# #### Task 14: Count Employees in Each Department
#
# Calculate the number of employees in each department. Display the result.

# %%
#here we use 'from pyspark.sql.functions import count' - imported earlier

# Calculate the number of employees in each department
employee_count_by_dept_df = employees_df.groupBy("Department").agg(count("Emp_No").alias("EmployeeCount"))

# Display the result
employee_count_by_dept_df.show()
# Out:
# +----------+-------------+
# |Department|EmployeeCount|
# +----------+-------------+
# |     Sales|           13|
# |        HR|            8|
# |   Finance|           10|
# | Marketing|            9|
# |        IT|           10|
# +----------+-------------+

# %% [markdown]
# #### Task 15: Filter Employees with the letter o in the Name
#
# Apply a filter to select records where the employee's name contains the letter `'o'`. Display the filtered DataFrame.

# %%
# here we use 'from pyspark.sql.functions import col' - imported earlier

# Apply a filter to select records where the employee's name contains the letter 'o'
employees_with_o_df = employees_df.filter(col("Emp_Name").contains('o'))

# Display the filtered DataFrame
employees_with_o_df.show()
# Out:
# +------+-----------+------+----+----------+
# |Emp_No|   Emp_Name|Salary| Age|Department|
# +------+-----------+------+----+----------+
# |   198|     Donald|  2600|29.0|        IT|
# |   199|    Douglas|  2600|34.0|     Sales|
# |   110|       John|  8200|31.0| Marketing|
# |   112|Jose Manuel|  7800|34.0|        HR|
# |   130|      Mozhe|  2800|28.0| Marketing|
# |   133|      Jason|  3300|38.0|     Sales|
# |   139|       John|  2700|36.0|     Sales|
# |   140|     Joshua|  2500|29.0|   Finance|
# +------+-----------+------+----+----------+

# %% [markdown]
# # Congratulations! You have completed the project.
#
# Now you know how to create a DataFrame from a CSV data file and perform a variety of DataFrame transformations and actions using Spark SQL.

# %% [markdown]
# ## Authors

# %% [markdown]
# Raghul Ramesh

# %% [markdown]
# Lavanya T S

# %% [markdown]
# <!--## Change Log -->

# %% [markdown]
# <!--|Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-09-01|0.1|Lavanya T S|Initial version|
# |2023-09-11|0.2|Pornima More|QA pass with edits|-->

# %% [markdown]
# <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
